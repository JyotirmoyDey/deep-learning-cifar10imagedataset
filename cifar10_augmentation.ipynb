# %% [markdown]
# # Artificial Intelligence Nanodegree
#
# ## Convolutional Neural Networks
#
# ---
#
# In this notebook, we train a CNN on augmented images from the CIFAR-10 database.
#
# ### 1. Load CIFAR-10 Database

# %%
import keras
from keras.datasets import cifar10

# load the pre-shuffled train and test data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# %% [markdown]
# ### 2. Visualize the First 24 Training Images

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ### 3. Rescale the Images by Dividing Every Pixel in Every Image by 255

# %%
# rescale [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %% [markdown]
# ### 4.  Break Dataset into Training, Testing, and Validation Sets

# %%
from keras.utils import np_utils

# break training set into training and validation sets
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# one-hot encode the labels
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
y_valid = keras.utils.to_categorical(y_valid, num_classes)

# print shape of training set
print('x_train shape:', x_train.shape)

# print number of training, validation, and test images
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# x_train shape: (45000, 32, 32, 3)
# 45000 train samples
# 10000 test samples
# 5000 validation samples

# %% [markdown]
# ### 5. Create and Configure Augmented Image Generator

# %%
from keras.preprocessing.image import ImageDataGenerator

# create and configure augmented image generator
datagen_train = ImageDataGenerator(
    width_shift_range=0.1,  # randomly shift images horizontally (10% of total width)
    height_shift_range=0.1,  # randomly shift images vertically (10% of total height)
    horizontal_flip=True) # randomly flip images horizontally

# fit augmented image generator on data
datagen_train.fit(x_train)

# %% [markdown]
# ### 6. Visualize Original and Augmented Images

# %%
import matplotlib.pyplot as plt

# take subset of training data
x_train_subset = x_train[:12]

# visualize subset of training data
fig = plt.figure(figsize=(20,2))
for i in range(0, len(x_train_subset)):
    ax = fig.add_subplot(1, 12, i+1)
    ax.imshow(x_train_subset[i])
fig.suptitle('Subset of Original Training Images', fontsize=20)
plt.show()

# visualize augmented images
fig = plt.figure(figsize=(20,2))
for x_batch in datagen_train.flow(x_train_subset, batch_size=12):
    for i in range(0, 12):
        ax = fig.add_subplot(1, 12, i+1)
        ax.imshow(x_batch[i])
    fig.suptitle('Augmented Images', fontsize=20)
    plt.show()
    break;

# %% [markdown]
# ### 7. Define the Model Architecture

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=32, kernel_size=3, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(Conv2D(filters=32, kernel_size=3, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.25))


model.add(Conv2D(filters=64, kernel_size=3, padding='same', activation='relu'))
model.add(Conv2D(filters=64, kernel_size=3, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))


model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_18 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 32, 32, 32)        9248
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 16, 16, 64)        18496
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 16, 16, 64)        36928
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 8, 8, 64)          0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 4096)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 512)               2097664
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 10)                5130
# =================================================================
# Total params: 2,168,362
# Trainable params: 2,168,362
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 8. Compile the Model

# %%
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', 
                  metrics=['accuracy'])

# %% [markdown]
# ### 9. Train the Model

# %%
from keras.callbacks import ModelCheckpoint   

batch_size = 256
epochs = 25

# train the model
checkpointer = ModelCheckpoint(filepath='aug_model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
model.fit_generator(datagen_train.flow(x_train, y_train, batch_size=batch_size),
                    steps_per_epoch=x_train.shape[0] // batch_size,
                    epochs=epochs, verbose=2, callbacks=[checkpointer],
                    validation_data=(x_valid, y_valid),
                    validation_steps=x_valid.shape[0] // batch_size)
# Out:
# Epoch 1/25
#  - 62s - loss: 1.9527 - acc: 0.2928 - val_loss: 1.6776 - val_acc: 0.3956
#
# Epoch 00001: val_loss improved from inf to 1.67757, saving model to aug_model.weights.best.hdf5
# Epoch 2/25
#  - 58s - loss: 1.5683 - acc: 0.4366 - val_loss: 1.3227 - val_acc: 0.5286
#
# Epoch 00002: val_loss improved from 1.67757 to 1.32265, saving model to aug_model.weights.best.hdf5
# Epoch 3/25
#  - 61s - loss: 1.3717 - acc: 0.5120 - val_loss: 1.1122 - val_acc: 0.6110
#
# Epoch 00003: val_loss improved from 1.32265 to 1.11219, saving model to aug_model.weights.best.hdf5
# Epoch 4/25
#  - 60s - loss: 1.2404 - acc: 0.5576 - val_loss: 0.9662 - val_acc: 0.6590
#
# Epoch 00004: val_loss improved from 1.11219 to 0.96621, saving model to aug_model.weights.best.hdf5
# Epoch 5/25
#  - 61s - loss: 1.1451 - acc: 0.5928 - val_loss: 0.9316 - val_acc: 0.6756
#
# Epoch 00005: val_loss improved from 0.96621 to 0.93162, saving model to aug_model.weights.best.hdf5
# Epoch 6/25
#  - 60s - loss: 1.0744 - acc: 0.6204 - val_loss: 0.9715 - val_acc: 0.6646
#
# Epoch 00006: val_loss did not improve from 0.93162
# Epoch 7/25
#  - 61s - loss: 1.0142 - acc: 0.6425 - val_loss: 0.8174 - val_acc: 0.7062
#
# Epoch 00007: val_loss improved from 0.93162 to 0.81735, saving model to aug_model.weights.best.hdf5
# Epoch 8/25
#  - 60s - loss: 0.9609 - acc: 0.6631 - val_loss: 0.8177 - val_acc: 0.7102
#
# Epoch 00008: val_loss did not improve from 0.81735
# Epoch 9/25
#  - 60s - loss: 0.9201 - acc: 0.6754 - val_loss: 0.8568 - val_acc: 0.6976
#
# Epoch 00009: val_loss did not improve from 0.81735
# Epoch 10/25
#  - 63s - loss: 0.8919 - acc: 0.6886 - val_loss: 0.7822 - val_acc: 0.7252
#
# Epoch 00010: val_loss improved from 0.81735 to 0.78218, saving model to aug_model.weights.best.hdf5
# Epoch 11/25
#  - 62s - loss: 0.8592 - acc: 0.6968 - val_loss: 0.6886 - val_acc: 0.7582
#
# Epoch 00011: val_loss improved from 0.78218 to 0.68860, saving model to aug_model.weights.best.hdf5
# Epoch 12/25
#  - 62s - loss: 0.8312 - acc: 0.7099 - val_loss: 0.6694 - val_acc: 0.7664
#
# Epoch 00012: val_loss improved from 0.68860 to 0.66936, saving model to aug_model.weights.best.hdf5
# Epoch 13/25
#  - 61s - loss: 0.8155 - acc: 0.7151 - val_loss: 0.6813 - val_acc: 0.7582
#
# Epoch 00013: val_loss did not improve from 0.66936
# Epoch 14/25
#  - 61s - loss: 0.7937 - acc: 0.7232 - val_loss: 0.6815 - val_acc: 0.7666
#
# Epoch 00014: val_loss did not improve from 0.66936
# Epoch 15/25
#  - 62s - loss: 0.7705 - acc: 0.7337 - val_loss: 0.6230 - val_acc: 0.7854
#
# Epoch 00015: val_loss improved from 0.66936 to 0.62296, saving model to aug_model.weights.best.hdf5
# Epoch 16/25
#  - 62s - loss: 0.7576 - acc: 0.7371 - val_loss: 0.6391 - val_acc: 0.7800
#
# Epoch 00016: val_loss did not improve from 0.62296
# Epoch 17/25
#  - 60s - loss: 0.7461 - acc: 0.7389 - val_loss: 0.6588 - val_acc: 0.7706
#
# Epoch 00017: val_loss did not improve from 0.62296
# Epoch 18/25
#  - 58s - loss: 0.7343 - acc: 0.7465 - val_loss: 0.6587 - val_acc: 0.7776
#
# Epoch 00018: val_loss did not improve from 0.62296
# Epoch 19/25
#  - 57s - loss: 0.7242 - acc: 0.7509 - val_loss: 0.6816 - val_acc: 0.7768
#
# Epoch 00019: val_loss did not improve from 0.62296
# Epoch 20/25
#  - 57s - loss: 0.7102 - acc: 0.7548 - val_loss: 0.6635 - val_acc: 0.7762
#
# Epoch 00020: val_loss did not improve from 0.62296
# Epoch 21/25
#  - 57s - loss: 0.7035 - acc: 0.7551 - val_loss: 0.6070 - val_acc: 0.7986
#
# Epoch 00021: val_loss improved from 0.62296 to 0.60698, saving model to aug_model.weights.best.hdf5
# Epoch 22/25
#  - 57s - loss: 0.6950 - acc: 0.7596 - val_loss: 0.5714 - val_acc: 0.8088
#
# Epoch 00022: val_loss improved from 0.60698 to 0.57143, saving model to aug_model.weights.best.hdf5
# Epoch 23/25
#  - 58s - loss: 0.6906 - acc: 0.7640 - val_loss: 0.6075 - val_acc: 0.8024
#
# Epoch 00023: val_loss did not improve from 0.57143
# Epoch 24/25
#  - 60s - loss: 0.6837 - acc: 0.7656 - val_loss: 0.5492 - val_acc: 0.8118
#
# Epoch 00024: val_loss improved from 0.57143 to 0.54922, saving model to aug_model.weights.best.hdf5
# Epoch 25/25
#  - 59s - loss: 0.6741 - acc: 0.7693 - val_loss: 0.5813 - val_acc: 0.8088
#
# Epoch 00025: val_loss did not improve from 0.54922

# %% [markdown]
# ### 10. Load the Model with the Best Validation Accuracy

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('aug_model.weights.best.hdf5')

# %% [markdown]
# ### 11. Calculate Classification Accuracy on Test Set

# %%
# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.8017
